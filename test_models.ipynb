# %%
from sql_operations import list_tables, describe_table, run_sql_query
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://chinook:chinook@localhost:5433/chinook_auto_increment')

# %%
[describe_table(engine, table) for table in eval(list_tables(engine))]
# Out:
# ['["{\'name\': \'artist_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'name\', \'type\': VARCHAR(length=120), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'album_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'title\', \'type\': VARCHAR(length=160), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'artist_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'employee_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'last_name\', \'type\': VARCHAR(length=20), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'first_name\', \'type\': VARCHAR(length=20), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'title\', \'type\': VARCHAR(length=30), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'reports_to\', \'type\': INTEGER(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'birth_date\', \'type\': TIMESTAMP(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'hire_date\', \'type\': TIMESTAMP(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'address\', \'type\': VARCHAR(length=70), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'city\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'state\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'country\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'postal_code\', \'type\': VARCHAR(length=10), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'phone\', \'type\': VARCHAR(length=24), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'fax\', \'type\': VARCHAR(length=24), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'email\', \'type\': VARCHAR(length=60), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'customer_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'first_name\', \'type\': VARCHAR(length=40), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'last_name\', \'type\': VARCHAR(length=20), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'company\', \'type\': VARCHAR(length=80), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'address\', \'type\': VARCHAR(length=70), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'city\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'state\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'country\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'postal_code\', \'type\': VARCHAR(length=10), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'phone\', \'type\': VARCHAR(length=24), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'fax\', \'type\': VARCHAR(length=24), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'email\', \'type\': VARCHAR(length=60), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'support_rep_id\', \'type\': INTEGER(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'invoice_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'customer_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'invoice_date\', \'type\': TIMESTAMP(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'billing_address\', \'type\': VARCHAR(length=70), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'billing_city\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'billing_state\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'billing_country\', \'type\': VARCHAR(length=40), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'billing_postal_code\', \'type\': VARCHAR(length=10), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'total\', \'type\': NUMERIC(precision=10, scale=2), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'invoice_line_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'invoice_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'track_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'unit_price\', \'type\': NUMERIC(precision=10, scale=2), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'quantity\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'track_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'name\', \'type\': VARCHAR(length=200), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'album_id\', \'type\': INTEGER(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'media_type_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'genre_id\', \'type\': INTEGER(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'composer\', \'type\': VARCHAR(length=220), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'milliseconds\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'bytes\', \'type\': INTEGER(), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'unit_price\', \'type\': NUMERIC(precision=10, scale=2), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'playlist_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'name\', \'type\': VARCHAR(length=120), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'playlist_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}", "{\'name\': \'track_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'genre_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'name\', \'type\': VARCHAR(length=120), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}"]',
#  '["{\'name\': \'media_type_id\', \'type\': INTEGER(), \'nullable\': False, \'default\': None, \'autoincrement\': True, \'comment\': None, \'identity\': {\'always\': True, \'start\': 1, \'increment\': 1, \'minvalue\': 1, \'maxvalue\': 2147483647, \'cache\': 1, \'cycle\': False}}", "{\'name\': \'name\', \'type\': VARCHAR(length=120), \'nullable\': True, \'default\': None, \'autoincrement\': False, \'comment\': None}"]']
